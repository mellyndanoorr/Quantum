# %%
pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\user\anaconda3\lib\site-packages (0.46.1)
# Requirement already satisfied: qiskit-terra==0.46.1 in c:\users\user\anaconda3\lib\site-packages (from qiskit) (0.46.1)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (0.15.1)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (1.26.4)
# Requirement already satisfied: ply>=3.10 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (5.9.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from qiskit-terra==0.46.1->qiskit) (5.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.46.1->qiskit) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.46.1->qiskit) (6.1.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.46.1->qiskit) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import qiskit
print(qiskit.__version__)
# Out:
# 0.46.1

# %%
import numpy as np
import math
from math import sqrt
from qiskit import ClassicalRegister, QuantumRegister, QuantumCircuit
from qiskit import execute, Aer, BasicAer
from qiskit.tools.visualization import circuit_drawer
from qiskit.tools.visualization import plot_histogram
from qiskit.tools.visualization import plot_bloch_multivector
from qiskit.quantum_info import Statevector
from qiskit import transpile
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4820\3115452656.py:5: DeprecationWarning: BasicAer is deprecated since Qiskit 0.46 and will be removed in Qiskit 1.0. The BasicAer (qiskit.providers.basicaer) module has been superseded by  qiskit.providers.basic_provider, and all its classes have been renamed to follow a new naming convention. More information and migration guidelines can be found in the 0.46 API docs for BasicAer.
#   from qiskit import execute, Aer, BasicAer

# %%
qc = QuantumCircuit(3, 3) 
qc.h(0)
qc.h(1)
qc.h(2)
qc.barrier()                  # Beri batas (tidak diproses)
qc.x(0)
qc.cx(1,2)
qc.y(2)
qc.barrier()                  # Beri batas (tidak diproses)
qc.ccx(0,1,2)
qc.x(0)
qc.y(1)
qc.barrier()                  # Beri batas (tidak diproses)
qc.z(1)
qc.swap(0,2)
qc.barrier()                  # Beri batas (tidak diproses)
qc.draw('mpl')

# %%
# Keadaan Akhir dari qc
psi=Statevector(qc)
psi.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{4} |000\rangle- \frac{\sqrt{2}}{4} |001\rangle- \frac{\sqrt{2}}{4} |010\rangle+\frac{\sqrt{2}}{4} |011\rangle- \frac{\sqrt{2}}{4} |100\rangle+\frac{\sqrt{2}}{4} |101\rangle- \frac{\sqrt{2}}{4} |110\rangle+\frac{\sqrt{2}}{4} |111\rangle$$

# %%
qc. measure_all()             # Pengukuran pada seluruh qubit
qc.draw('mpl')                # Tampilkan gambar sirkuit di layar

# %%
qc = QuantumCircuit(3) 
qc.h(0)
qc.x(1)
qc.h(2)
qc.barrier()                  # Beri batas (tidak diproses)
qc.cx(0,1)
qc.z(2)
qc.z(0)
qc.barrier()                  # Beri batas (tidak diproses)
qc.z(0)
qc.z(2)
qc.cx(0,1)
qc.barrier()                  # Beri batas (tidak diproses)
qc.h(0)
qc.x(1)
qc.h(2)
qc.draw('mpl')

# %%
# Keadaan Akhir dari qc
psi_1=Statevector(qc)
psi_1.draw('latex')
# Out:
# $$ |000\rangle$$

# %%
qc = QuantumCircuit(3) 
qc.h(0)
qc.h(1)
qc.h(2)
qc.barrier()                  # Beri batas (tidak diproses)
qc.x(1)
qc.h(2)
qc.ccx(0,1,2)
qc.x(1)
qc.h(2)
qc.barrier()                  # Beri batas (tidak diproses)
qc.draw('mpl')

# %%
psi_1=Statevector(qc)
psi_1.draw('latex')
